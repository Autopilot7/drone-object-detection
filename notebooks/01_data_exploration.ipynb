# %% [markdown]
# # Data Exploration - Drone Object Detection Challenge
#
# This notebook explores the training dataset to understand:
# - Dataset structure and statistics
# - Video properties (resolution, fps, duration)
# - Reference image characteristics
# - Annotation statistics
# - Object appearance patterns

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from pathlib import Path
from tqdm import tqdm

from src.data_loader import DroneDataset
from src.utils.video_utils import get_video_info, extract_frame_at_index
from src.config import DATA_ROOT

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## Load Dataset

# %%
dataset = DroneDataset(DATA_ROOT)

print(f"Total samples: {len(dataset)}")
print(f"Video IDs: {dataset.get_video_ids()}")
print(f"Categories: {dataset.get_categories()}")
